# %%
#a)Import the “train.csv” data you downloaded (from NTU Learn) in Jupyter Notebook.
import pandas as pd
train_df=pd.read_csv("/Users/russell/NTU/Y2S2/MS0003/Tutorials/Tut_2/train.csv")

# %%
#b)Open the “data_description.txt” file you downloaded (from NTU Learn) in Wordpad.
#Read the description for each variable carefully and try to identify the “actual” Numeric variables.
#numeric varibles:LotFrontage, LotArea,MasVnrArea, BsmtFinSF2,
#     BsmtUnfSF, TotRmsAbvGrd, Fireplaces, GarageCars, GarageArea, 
#     WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MoSold

# %%
#c)Drop non-Numeric variables from the DataFrame
#to have a clean DataFrame with Numeric variables.
train_clean=train_df[["LotFrontage", "LotArea","MasVnrArea", "BsmtFinSF2",
     "BsmtUnfSF", "TotRmsAbvGrd", "Fireplaces", "GarageCars", "GarageArea", 
    "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea", "MoSold","MiscVal","SalePrice"]]
train_clean
# Out:
#       LotFrontage  LotArea  MasVnrArea  BsmtFinSF2  BsmtUnfSF  TotRmsAbvGrd  \
# 0            65.0     8450       196.0           0        150             8
# 1            80.0     9600         0.0           0        284             6
# 2            68.0    11250       162.0           0        434             6
# 3            60.0     9550         0.0           0        540             7
# 4            84.0    14260       350.0           0        490             9
# ...           ...      ...         ...         ...        ...           ...
# 1455         62.0     7917         0.0           0        953             7
# 1456         85.0    13175       119.0         163        589             7
# 1457         66.0     9042         0.0           0        877             9
# 1458         68.0     9717         0.0        1029          0             5
# 1459         75.0     9937         0.0         290        136             6
#
# ...

# %%
#d)Find the Summary Statistics (Mean, Median, Quartiles etc) of SalePrice from the Numeric DataFrame.
sp=train_df["SalePrice"]
sp.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#e) Visualize the summary statistics and distribution of SalePrice using standard Box-Plot, Histogram, KDE.
import plotly.express as px
fig=px.box(data_frame=train_df, y= "SalePrice",title="Box plot  of SalePrice").show()
#Histogram
px.histogram(
    data_frame=train_df,
    x="SalePrice",
    nbins=50,
    title="Distribution of SalePrice").show()
#KDE
px.line(train_df, x="SalePrice",title="SalePrice Distribution").show()

# %%
import seaborn as sb
import matplotlib.pyplot as plt
f, axes = plt.subplots(1, 1, figsize=(24, 12))
sb.boxplot(data=train_df["SalePrice"], orient="h")
# Out:
# <Axes: xlabel='SalePrice'>

# %%
#h)Plot SalePrice (y-axis) vs LotArea (x-axis) using jointplot and check the Correlation between the two.
import seaborn as sb
import matplotlib.pyplot as plt

# Joint plot
sb.jointplot(
    data=train_df,
    x="LotArea",
    y="SalePrice",
    kind="scatter")
plt.show()

corr = train_df["LotArea"].corr(train_df["SalePrice"])
corr
# Out:
# np.float64(0.2638433538714056)

# %%
houseNumData = pd.DataFrame(train_df[['LotArea', 'GrLivArea', 'TotalBsmtSF', 'GarageArea', 'SalePrice']])
houseNumData
# Out:
#       LotArea  GrLivArea  TotalBsmtSF  GarageArea  SalePrice
# 0        8450       1710          856         548     208500
# 1        9600       1262         1262         460     181500
# 2       11250       1786          920         608     223500
# 3        9550       1717          756         642     140000
# 4       14260       2198         1145         836     250000
# ...       ...        ...          ...         ...        ...
# 1455     7917       1647          953         460     175000
# 1456    13175       2073         1542         500     210000
# 1457     9042       2340         1152         252     266500
# 1458     9717       1078         1078         240     142125
# 1459     9937       1256         1256         276     147500
#
# [1460 rows x 5 columns]

# %%
#a)Check the individual statistical description and 
# visualize the statistical distributions of each of these variables.

# %%
#b)Comment if the distributions look like “Normal Distribution”, or different. Use the .skew() method
# to find the “skewness” of each of the five distributions. Which of the variables has the maximum
# number of outliers?

# %%
#c)Check the relationship amongst the variables using mutual correlation and the correlation heatmap.
# Comment which of the variables has the strongest correlation with “SalePrice”. Is this useful in
# predicting “SalePrice”?

# %%
#d)Check the relationship amongst the variables using mutual jointplots with “SalePrice” as one of the
#axies and also using an overall pairplot.
LotAreacorr = train_df["LotArea"].corr(train_df["SalePrice"])
GrLivAreacorr = train_df["GrLivArea"].corr(train_df["SalePrice"])
TotalBsmtSFcorr = train_df["TotalBsmtSF"].corr(train_df["SalePrice"])
GarageAreacorr = train_df["GarageArea"].corr(train_df["SalePrice"])
print(
    f"LotArea vs SalePrice: {LotAreacorr:.3f}\n"
    f"GrLivArea vs SalePrice: {GrLivAreacorr:.3f}\n"
    f"TotalBsmtSF vs SalePrice: {TotalBsmtSFcorr:.3f}\n"
    f"GarageArea vs SalePrice: {GarageAreacorr:.3f}"
)
#fstring is needed as usually ipynb prints only the last line
# Out:
# LotArea vs SalePrice: 0.264
# GrLivArea vs SalePrice: 0.709
# TotalBsmtSF vs SalePrice: 0.614
# GarageArea vs SalePrice: 0.623
